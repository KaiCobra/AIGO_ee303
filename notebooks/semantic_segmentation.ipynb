# %%
# Copyright (c) Meta Platforms, Inc. and affiliates.

# %% [markdown]
# # Semantic Segmentation <a target="_blank" href="https://colab.research.google.com/github/facebookresearch/dinov2/blob/main/notebooks/semantic_segmentation.ipynb"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import sys

INSTALL = True # Switch this to install dependencies
if INSTALL: # Try installing package with extras
    REPO_URL = "https://github.com/facebookresearch/dinov2"
    # !{sys.executable} -m pip install -e {REPO_URL}'[extras]' --extra-index-url https://download.pytorch.org/whl/cu117  --extra-index-url https://pypi.nvidia.com
else:
    REPO_PATH = "<FIXME>" # Specify a local path to the repository (or use installed package instead)
    sys.path.append(REPO_PATH)
# Out:
# ERROR: https://github.com/facebookresearch/dinov2[extras] is not a valid editable requirement. It should either be a path to a local project or a VCS URL (beginning with bzr+http, bzr+https, bzr+ssh, bzr+sftp, bzr+ftp, bzr+lp, bzr+file, git+http, git+https, git+ssh, git+git, git+file, hg+file, hg+http, hg+https, hg+ssh, hg+static-http, svn+ssh, svn+http, svn+https, svn+svn, svn+file).

# %%
# !git clone https://github.com/facebookresearch/dinov2.git
# %cd /content
# %cd dinov2
# !pip install -e .[extras]
# Out:
# fatal: destination path 'dinov2' already exists and is not an empty directory.
# /content
# /content/dinov2
# Obtaining file:///content/dinov2
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
# Collecting torch==2.2.0 (from dinov2==0.0.1)
#   Using cached torch-2.2.0-cp312-cp312-manylinux1_x86_64.whl.metadata (25 kB)
# Collecting torchvision==0.17.0 (from dinov2==0.0.1)
#   Using cached torchvision-0.17.0-cp312-cp312-manylinux1_x86_64.whl.metadata (6.6 kB)
# Requirement already satisfied: omegaconf in /usr/local/lib/python3.12/dist-packages (from dinov2==0.0.1) (2.3.0)
# Collecting torchmetrics==0.10.3 (from dinov2==0.0.1)
#   Using cached torchmetrics-0.10.3-py3-none-any.whl.metadata (15 kB)
# Collecting fvcore (from dinov2==0.0.1)
#   Using cached fvcore-0.1.5.post20221221.tar.gz (50 kB)
#   Preparing metadata (setup.py) ... done
# Collecting iopath (from dinov2==0.0.1)
#   Using cached iopath-0.1.10.tar.gz (42 kB)
#   Preparing metadata (setup.py) ... done
# Collecting xformers==0.0.21 (from dinov2==0.0.1)
#   Downloading xformers-0.0.21.tar.gz (22.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 22.3/22.3 MB 60.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting submitit (from dinov2==0.0.1)
#   Downloading submitit-1.5.3-py3-none-any.whl.metadata (7.9 kB)
# Collecting cuml-cu11 (from dinov2==0.0.1)
#   Downloading cuml_cu11-25.6.0.tar.gz (2.5 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch==2.2.0->dinov2==0.0.1) (3.19.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.12/dist-packages (from torch==2.2.0->dinov2==0.0.1) (4.15.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.12/dist-packages (from torch==2.2.0->dinov2==0.0.1) (1.13.3)
# Requirement already satisfied: networkx in /usr/local/lib/python3.12/dist-packages (from torch==2.2.0->dinov2==0.0.1) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch==2.2.0->dinov2==0.0.1) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.12/dist-packages (from torch==2.2.0->dinov2==0.0.1) (2025.3.0)
# Collecting nvidia-cuda-nvrtc-cu12==12.1.105 (from torch==2.2.0->dinov2==0.0.1)
#   Downloading nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.1.105 (from torch==2.2.0->dinov2==0.0.1)
#   Downloading nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.1.105 (from torch==2.2.0->dinov2==0.0.1)
#   Downloading nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==8.9.2.26 (from torch==2.2.0->dinov2==0.0.1)
#   Downloading nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.1.3.1 (from torch==2.2.0->dinov2==0.0.1)
#   Downloading nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.0.2.54 (from torch==2.2.0->dinov2==0.0.1)
#   Downloading nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.2.106 (from torch==2.2.0->dinov2==0.0.1)
#   Downloading nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.4.5.107 (from torch==2.2.0->dinov2==0.0.1)
#   Downloading nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.1.0.106 (from torch==2.2.0->dinov2==0.0.1)
#   Downloading nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-nccl-cu12==2.19.3 (from torch==2.2.0->dinov2==0.0.1)
#   Downloading nvidia_nccl_cu12-2.19.3-py3-none-manylinux1_x86_64.whl.metadata (1.8 kB)
# Collecting nvidia-nvtx-cu12==12.1.105 (from torch==2.2.0->dinov2==0.0.1)
#   Downloading nvidia_nvtx_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.7 kB)
# Collecting triton==2.2.0 (from torch==2.2.0->dinov2==0.0.1)
#   Downloading triton-2.2.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (1.4 kB)
# Requirement already satisfied: numpy>=1.17.2 in /usr/local/lib/python3.12/dist-packages (from torchmetrics==0.10.3->dinov2==0.0.1) (2.0.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from torchmetrics==0.10.3->dinov2==0.0.1) (25.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from torchvision==0.17.0->dinov2==0.0.1) (2.32.4)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.12/dist-packages (from torchvision==0.17.0->dinov2==0.0.1) (11.3.0)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /usr/local/lib/python3.12/dist-packages (from nvidia-cusolver-cu12==11.4.5.107->torch==2.2.0->dinov2==0.0.1) (12.6.85)
# Collecting mmcv-full==1.5.0 (from dinov2==0.0.1)
#   Downloading mmcv-full-1.5.0.tar.gz (530 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 530.8/530.8 kB 25.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting mmsegmentation==0.27.0 (from dinov2==0.0.1)
#   Downloading mmsegmentation-0.27.0-py3-none-any.whl.metadata (13 kB)
# Collecting addict (from mmcv-full==1.5.0->dinov2==0.0.1)
#   Downloading addict-2.4.0-py3-none-any.whl.metadata (1.0 kB)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.12/dist-packages (from mmcv-full==1.5.0->dinov2==0.0.1) (6.0.2)
# Collecting yapf (from mmcv-full==1.5.0->dinov2==0.0.1)
#   Downloading yapf-0.43.0-py3-none-any.whl.metadata (46 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.8/46.8 kB 4.3 MB/s eta 0:00:00
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (from mmsegmentation==0.27.0->dinov2==0.0.1) (3.10.0)
# Collecting mmcls>=0.20.1 (from mmsegmentation==0.27.0->dinov2==0.0.1)
#   Downloading mmcls-0.25.0-py2.py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: prettytable in /usr/local/lib/python3.12/dist-packages (from mmsegmentation==0.27.0->dinov2==0.0.1) (3.16.0)
# Collecting cuda-python<12.0a0,>=11.8.5 (from cuml-cu11->dinov2==0.0.1)
#   Downloading cuda_python-11.8.7-py3-none-any.whl.metadata (14 kB)
# Collecting cudf-cu11==25.6.* (from cuml-cu11->dinov2==0.0.1)
#   Downloading cudf_cu11-25.6.0.tar.gz (2.7 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting cupy-cuda11x>=12.0.0 (from cuml-cu11->dinov2==0.0.1)
#   Downloading cupy_cuda11x-13.6.0-cp312-cp312-manylinux2014_x86_64.whl.metadata (2.4 kB)
# Collecting cuvs-cu11==25.6.* (from cuml-cu11->dinov2==0.0.1)
#   Downloading cuvs_cu11-25.6.1.tar.gz (1.0 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: dask-cuda==25.6.* in /usr/local/lib/python3.12/dist-packages (from cuml-cu11->dinov2==0.0.1) (25.6.0)
# Collecting dask-cudf-cu11==25.6.* (from cuml-cu11->dinov2==0.0.1)
#   Downloading dask_cudf_cu11-25.6.0.tar.gz (2.4 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.12/dist-packages (from cuml-cu11->dinov2==0.0.1) (1.5.2)
# Collecting libcuml-cu11==25.6.* (from cuml-cu11->dinov2==0.0.1)
#   Downloading libcuml_cu11-25.6.0.tar.gz (4.1 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: numba<0.62.0a0,>=0.59.1 in /usr/local/lib/python3.12/dist-packages (from cuml-cu11->dinov2==0.0.1) (0.60.0)
# Collecting nvidia-cublas-cu11 (from cuml-cu11->dinov2==0.0.1)
#   Downloading nvidia_cublas_cu11-11.11.3.6-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu11 (from cuml-cu11->dinov2==0.0.1)
#   Downloading nvidia_cufft_cu11-10.9.0.58-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu11 (from cuml-cu11->dinov2==0.0.1)
#   Downloading nvidia_curand_cu11-10.3.0.86-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu11 (from cuml-cu11->dinov2==0.0.1)
#   Downloading nvidia_cusolver_cu11-11.4.1.48-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu11 (from cuml-cu11->dinov2==0.0.1)
#   Downloading nvidia_cusparse_cu11-11.7.5.86-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting pylibraft-cu11==25.6.* (from cuml-cu11->dinov2==0.0.1)
#   Downloading pylibraft_cu11-25.6.0.tar.gz (5.6 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting raft-dask-cu11==25.6.* (from cuml-cu11->dinov2==0.0.1)
#   Downloading raft_dask_cu11-25.6.0.tar.gz (5.6 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: rapids-dask-dependency==25.6.* in /usr/local/lib/python3.12/dist-packages (from cuml-cu11->dinov2==0.0.1) (25.6.0)
# Collecting rmm-cu11==25.6.* (from cuml-cu11->dinov2==0.0.1)
#   Downloading rmm_cu11-25.6.0.tar.gz (14 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: scikit-learn>=1.5 in /usr/local/lib/python3.12/dist-packages (from cuml-cu11->dinov2==0.0.1) (1.6.1)
# Requirement already satisfied: scipy>=1.8.0 in /usr/local/lib/python3.12/dist-packages (from cuml-cu11->dinov2==0.0.1) (1.16.2)
# Requirement already satisfied: treelite==4.4.1 in /usr/local/lib/python3.12/dist-packages (from cuml-cu11->dinov2==0.0.1) (4.4.1)
# Requirement already satisfied: cachetools in /usr/local/lib/python3.12/dist-packages (from cudf-cu11==25.6.*->cuml-cu11->dinov2==0.0.1) (5.5.2)
# Collecting cubinlinker-cu11 (from cudf-cu11==25.6.*->cuml-cu11->dinov2==0.0.1)
#   Downloading cubinlinker_cu11-0.3.0.post3-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (308 bytes)
# Collecting libcudf-cu11==25.6.* (from cudf-cu11==25.6.*->cuml-cu11->dinov2==0.0.1)
#   Downloading libcudf_cu11-25.6.0.tar.gz (2.2 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: numba-cuda<0.12.0a0,>=0.11.0 in /usr/local/lib/python3.12/dist-packages (from cudf-cu11==25.6.*->cuml-cu11->dinov2==0.0.1) (0.11.0)
# Requirement already satisfied: nvtx>=0.2.1 in /usr/local/lib/python3.12/dist-packages (from cudf-cu11==25.6.*->cuml-cu11->dinov2==0.0.1) (0.2.13)
# Requirement already satisfied: pandas<2.2.4dev0,>=2.0 in /usr/local/lib/python3.12/dist-packages (from cudf-cu11==25.6.*->cuml-cu11->dinov2==0.0.1) (2.2.2)
# Collecting ptxcompiler-cu11 (from cudf-cu11==25.6.*->cuml-cu11->dinov2==0.0.1)
#   Downloading ptxcompiler_cu11-0.8.1.post3-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (323 bytes)
# Requirement already satisfied: pyarrow<20.0.0a0,>=14.0.0 in /usr/local/lib/python3.12/dist-packages (from cudf-cu11==25.6.*->cuml-cu11->dinov2==0.0.1) (18.1.0)
# Collecting pylibcudf-cu11==25.6.* (from cudf-cu11==25.6.*->cuml-cu11->dinov2==0.0.1)
#   Downloading pylibcudf_cu11-25.6.0.tar.gz (2.4 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: rich in /usr/local/lib/python3.12/dist-packages (from cudf-cu11==25.6.*->cuml-cu11->dinov2==0.0.1) (13.9.4)
# Collecting libcuvs-cu11==25.6.* (from cuvs-cu11==25.6.*->cuml-cu11->dinov2==0.0.1)
#   Downloading libcuvs_cu11-25.6.1.tar.gz (4.9 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: click>=8.1 in /usr/local/lib/python3.12/dist-packages (from dask-cuda==25.6.*->cuml-cu11->dinov2==0.0.1) (8.2.1)
# Requirement already satisfied: pynvml<13.0.0a0,>=12.0.0 in /usr/local/lib/python3.12/dist-packages (from dask-cuda==25.6.*->cuml-cu11->dinov2==0.0.1) (12.0.0)
# Requirement already satisfied: zict>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from dask-cuda==25.6.*->cuml-cu11->dinov2==0.0.1) (3.0.0)
# Collecting libraft-cu11==25.6.* (from libcuml-cu11==25.6.*->cuml-cu11->dinov2==0.0.1)
#   Downloading libraft_cu11-25.6.0.tar.gz (5.5 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: rapids-logger==0.1.* in /usr/local/lib/python3.12/dist-packages (from libcuml-cu11==25.6.*->cuml-cu11->dinov2==0.0.1) (0.1.1)
# Collecting distributed-ucxx-cu11==0.44.* (from raft-dask-cu11==25.6.*->cuml-cu11->dinov2==0.0.1)
#   Downloading distributed_ucxx_cu11-0.44.0.tar.gz (1.0 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting ucx-py-cu11==0.44.* (from raft-dask-cu11==25.6.*->cuml-cu11->dinov2==0.0.1)
#   Downloading ucx_py_cu11-0.44.0.tar.gz (1.4 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: dask==2025.5.0 in /usr/local/lib/python3.12/dist-packages (from rapids-dask-dependency==25.6.*->cuml-cu11->dinov2==0.0.1) (2025.5.0)
# Requirement already satisfied: distributed==2025.5.0 in /usr/local/lib/python3.12/dist-packages (from rapids-dask-dependency==25.6.*->cuml-cu11->dinov2==0.0.1) (2025.5.0)
# Collecting librmm-cu11==25.6.* (from rmm-cu11==25.6.*->cuml-cu11->dinov2==0.0.1)
#   Downloading librmm_cu11-25.6.0.tar.gz (13 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: cloudpickle>=3.0.0 in /usr/local/lib/python3.12/dist-packages (from dask==2025.5.0->rapids-dask-dependency==25.6.*->cuml-cu11->dinov2==0.0.1) (3.1.1)
# Requirement already satisfied: partd>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from dask==2025.5.0->rapids-dask-dependency==25.6.*->cuml-cu11->dinov2==0.0.1) (1.4.2)
# Requirement already satisfied: toolz>=0.10.0 in /usr/local/lib/python3.12/dist-packages (from dask==2025.5.0->rapids-dask-dependency==25.6.*->cuml-cu11->dinov2==0.0.1) (0.12.1)
# Requirement already satisfied: locket>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from distributed==2025.5.0->rapids-dask-dependency==25.6.*->cuml-cu11->dinov2==0.0.1) (1.0.0)
# Requirement already satisfied: msgpack>=1.0.2 in /usr/local/lib/python3.12/dist-packages (from distributed==2025.5.0->rapids-dask-dependency==25.6.*->cuml-cu11->dinov2==0.0.1) (1.1.1)
# Requirement already satisfied: psutil>=5.8.0 in /usr/local/lib/python3.12/dist-packages (from distributed==2025.5.0->rapids-dask-dependency==25.6.*->cuml-cu11->dinov2==0.0.1) (5.9.5)
# Requirement already satisfied: sortedcontainers>=2.0.5 in /usr/local/lib/python3.12/dist-packages (from distributed==2025.5.0->rapids-dask-dependency==25.6.*->cuml-cu11->dinov2==0.0.1) (2.4.0)
# Requirement already satisfied: tblib>=1.6.0 in /usr/local/lib/python3.12/dist-packages (from distributed==2025.5.0->rapids-dask-dependency==25.6.*->cuml-cu11->dinov2==0.0.1) (3.1.0)
# Requirement already satisfied: tornado>=6.2.0 in /usr/local/lib/python3.12/dist-packages (from distributed==2025.5.0->rapids-dask-dependency==25.6.*->cuml-cu11->dinov2==0.0.1) (6.4.2)
# Requirement already satisfied: urllib3>=1.26.5 in /usr/local/lib/python3.12/dist-packages (from distributed==2025.5.0->rapids-dask-dependency==25.6.*->cuml-cu11->dinov2==0.0.1) (2.5.0)
# Collecting ucxx-cu11==0.44.* (from distributed-ucxx-cu11==0.44.*->raft-dask-cu11==25.6.*->cuml-cu11->dinov2==0.0.1)
#   Downloading ucxx_cu11-0.44.0.tar.gz (3.2 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting libkvikio-cu11==25.6.* (from libcudf-cu11==25.6.*->cudf-cu11==25.6.*->cuml-cu11->dinov2==0.0.1)
#   Downloading libkvikio_cu11-25.6.0.tar.gz (2.0 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting libucx-cu11<1.19,>=1.15.0 (from ucx-py-cu11==0.44.*->raft-dask-cu11==25.6.*->cuml-cu11->dinov2==0.0.1)
#   Downloading libucx_cu11-1.18.1-py3-none-manylinux_2_28_x86_64.whl.metadata (2.9 kB)
# Collecting libucxx-cu11==0.44.* (from ucxx-cu11==0.44.*->distributed-ucxx-cu11==0.44.*->raft-dask-cu11==25.6.*->cuml-cu11->dinov2==0.0.1)
#   Downloading libucxx_cu11-0.44.0.tar.gz (3.0 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting yacs>=0.1.6 (from fvcore->dinov2==0.0.1)
#   Downloading yacs-0.1.8-py3-none-any.whl.metadata (639 bytes)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from fvcore->dinov2==0.0.1) (4.67.1)
# Requirement already satisfied: termcolor>=1.1 in /usr/local/lib/python3.12/dist-packages (from fvcore->dinov2==0.0.1) (3.1.0)
# Requirement already satisfied: tabulate in /usr/local/lib/python3.12/dist-packages (from fvcore->dinov2==0.0.1) (0.9.0)
# Collecting portalocker (from iopath->dinov2==0.0.1)
#   Downloading portalocker-3.2.0-py3-none-any.whl.metadata (8.7 kB)
# Requirement already satisfied: antlr4-python3-runtime==4.9.* in /usr/local/lib/python3.12/dist-packages (from omegaconf->dinov2==0.0.1) (4.9.3)
# Collecting cuda-bindings~=11.8.7 (from cuda-python<12.0a0,>=11.8.5->cuml-cu11->dinov2==0.0.1)
#   Downloading cuda_bindings-11.8.7-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (12 kB)
# Requirement already satisfied: fastrlock>=0.5 in /usr/local/lib/python3.12/dist-packages (from cupy-cuda11x>=12.0.0->cuml-cu11->dinov2==0.0.1) (0.8.3)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch==2.2.0->dinov2==0.0.1) (3.0.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mmsegmentation==0.27.0->dinov2==0.0.1) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mmsegmentation==0.27.0->dinov2==0.0.1) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mmsegmentation==0.27.0->dinov2==0.0.1) (4.60.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mmsegmentation==0.27.0->dinov2==0.0.1) (1.4.9)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mmsegmentation==0.27.0->dinov2==0.0.1) (3.2.4)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mmsegmentation==0.27.0->dinov2==0.0.1) (2.9.0.post0)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /usr/local/lib/python3.12/dist-packages (from numba<0.62.0a0,>=0.59.1->cuml-cu11->dinov2==0.0.1) (0.43.0)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn>=1.5->cuml-cu11->dinov2==0.0.1) (3.6.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.12/dist-packages (from prettytable->mmsegmentation==0.27.0->dinov2==0.0.1) (0.2.13)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->torchvision==0.17.0->dinov2==0.0.1) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->torchvision==0.17.0->dinov2==0.0.1) (3.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->torchvision==0.17.0->dinov2==0.0.1) (2025.8.3)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy->torch==2.2.0->dinov2==0.0.1) (1.3.0)
# Requirement already satisfied: platformdirs>=3.5.1 in /usr/local/lib/python3.12/dist-packages (from yapf->mmcv-full==1.5.0->dinov2==0.0.1) (4.4.0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas<2.2.4dev0,>=2.0->cudf-cu11==25.6.*->cuml-cu11->dinov2==0.0.1) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas<2.2.4dev0,>=2.0->cudf-cu11==25.6.*->cuml-cu11->dinov2==0.0.1) (2025.2)
# Requirement already satisfied: nvidia-ml-py<13.0.0a0,>=12.0.0 in /usr/local/lib/python3.12/dist-packages (from pynvml<13.0.0a0,>=12.0.0->dask-cuda==25.6.*->cuml-cu11->dinov2==0.0.1) (12.575.51)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib->mmsegmentation==0.27.0->dinov2==0.0.1) (1.17.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich->cudf-cu11==25.6.*->cuml-cu11->dinov2==0.0.1) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich->cudf-cu11==25.6.*->cuml-cu11->dinov2==0.0.1) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich->cudf-cu11==25.6.*->cuml-cu11->dinov2==0.0.1) (0.1.2)
# Downloading torch-2.2.0-cp312-cp312-manylinux1_x86_64.whl (755.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 755.4/755.4 MB 1.2 MB/s eta 0:00:00
# Downloading torchmetrics-0.10.3-py3-none-any.whl (529 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 529.7/529.7 kB 40.0 MB/s eta 0:00:00
# Downloading torchvision-0.17.0-cp312-cp312-manylinux1_x86_64.whl (6.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.9/6.9 MB 101.8 MB/s eta 0:00:00
# Downloading nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 410.6/410.6 MB 1.3 MB/s eta 0:00:00
# Downloading nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.1/14.1 MB 127.0 MB/s eta 0:00:00
# Downloading nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.7/23.7 MB 103.9 MB/s eta 0:00:00
# Downloading nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 823.6/823.6 kB 37.1 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 731.7/731.7 MB 1.9 MB/s eta 0:00:00
# Downloading nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.6/121.6 MB 7.7 MB/s eta 0:00:00
# Downloading nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.5/56.5 MB 14.2 MB/s eta 0:00:00
# Downloading nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 124.2/124.2 MB 7.7 MB/s eta 0:00:00
# Downloading nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 196.0/196.0 MB 5.7 MB/s eta 0:00:00
# Downloading nvidia_nccl_cu12-2.19.3-py3-none-manylinux1_x86_64.whl (166.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 166.0/166.0 MB 7.2 MB/s eta 0:00:00
# Downloading nvidia_nvtx_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (99 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 99.1/99.1 kB 9.7 MB/s eta 0:00:00
# Downloading triton-2.2.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (167.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 167.9/167.9 MB 6.2 MB/s eta 0:00:00
# Downloading mmsegmentation-0.27.0-py3-none-any.whl (817 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 817.6/817.6 kB 46.3 MB/s eta 0:00:00
# Downloading submitit-1.5.3-py3-none-any.whl (75 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.5/75.5 kB 7.2 MB/s eta 0:00:00
# Downloading cuda_python-11.8.7-py3-none-any.whl (11 kB)
# Downloading cupy_cuda11x-13.6.0-cp312-cp312-manylinux2014_x86_64.whl (99.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 99.7/99.7 MB 11.8 MB/s eta 0:00:00
# Downloading mmcls-0.25.0-py2.py3-none-any.whl (648 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 648.8/648.8 kB 46.8 MB/s eta 0:00:00
# Downloading yacs-0.1.8-py3-none-any.whl (14 kB)
# Downloading addict-2.4.0-py3-none-any.whl (3.8 kB)
# Downloading nvidia_cublas_cu11-11.11.3.6-py3-none-manylinux2014_x86_64.whl (417.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 417.9/417.9 MB 1.2 MB/s eta 0:00:00
# Downloading nvidia_cufft_cu11-10.9.0.58-py3-none-manylinux2014_x86_64.whl (168.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 168.4/168.4 MB 6.7 MB/s eta 0:00:00
# Downloading nvidia_curand_cu11-10.3.0.86-py3-none-manylinux2014_x86_64.whl (58.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.1/58.1 MB 14.1 MB/s eta 0:00:00
# Downloading nvidia_cusolver_cu11-11.4.1.48-py3-none-manylinux2014_x86_64.whl (128.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 128.2/128.2 MB 7.2 MB/s eta 0:00:00
# Downloading nvidia_cusparse_cu11-11.7.5.86-py3-none-manylinux2014_x86_64.whl (204.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 204.1/204.1 MB 3.9 MB/s eta 0:00:00
# Downloading portalocker-3.2.0-py3-none-any.whl (22 kB)
# Downloading yapf-0.43.0-py3-none-any.whl (256 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 256.2/256.2 kB 20.1 MB/s eta 0:00:00
# Downloading cuda_bindings-11.8.7-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (8.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.6/8.6 MB 28.7 MB/s eta 0:00:00
# Downloading cubinlinker_cu11-0.3.0.post3-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (8.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.8/8.8 MB 32.6 MB/s eta 0:00:00
# Downloading ptxcompiler_cu11-0.8.1.post3-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (8.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.8/8.8 MB 30.4 MB/s eta 0:00:00
# Downloading libucx_cu11-1.18.1-py3-none-manylinux_2_28_x86_64.whl (27.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 27.6/27.6 MB 64.7 MB/s eta 0:00:00
# Building wheels for collected packages: dinov2, xformers, mmcv-full, cuml-cu11, cudf-cu11, cuvs-cu11, dask-cudf-cu11, libcuml-cu11, pylibraft-cu11, raft-dask-cu11, rmm-cu11, distributed-ucxx-cu11, libcudf-cu11, libcuvs-cu11, libraft-cu11, librmm-cu11, pylibcudf-cu11, ucx-py-cu11, libkvikio-cu11, ucxx-cu11, libucxx-cu11, fvcore, iopath
#   Building editable for dinov2 (pyproject.toml) ... done
#   Created wheel for dinov2: filename=dinov2-0.0.1-0.editable-py3-none-any.whl size=12760 sha256=0397e81e8a8704fc5b0b7e1852d67d5885c3558ed418eac46c794f0cdf8561f3
#   Stored in directory: /tmp/pip-ephem-wheel-cache-zo7qal59/wheels/12/28/4c/ab9e8f97b52f4c0b9c3e3f7a548168263d5eb66282936c9f87
#   Building wheel for xformers (setup.py) ... done
#   Created wheel for xformers: filename=xformers-0.0.21-cp312-cp312-linux_x86_64.whl size=10284496 sha256=795baa8e5d2e4e5934215a38ffc601aa3c0a130fce85e679d600e61d7debfece
#   Stored in directory: /root/.cache/pip/wheels/98/5a/cc/34692c61b0f8acab9be0a460dd61448022e76eb02a9a1e3427
#   error: subprocess-exited-with-error
#
#   × python setup.py bdist_wheel did not run successfully.
#   │ exit code: 1
#   ╰─> See above for output.
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   Building wheel for mmcv-full (setup.py) ... error
#   ERROR: Failed building wheel for mmcv-full
#   Running setup.py clean for mmcv-full
#   Building wheel for cuml-cu11 (pyproject.toml) ... done
#   Created wheel for cuml-cu11: filename=cuml_cu11-25.6.0-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl size=8194616 sha256=7a055ddd489c74b59841b1628c2e41fd1a1a54282482a88b1c8a3dd0db52c3a9
#   Stored in directory: /root/.cache/pip/wheels/cf/cd/f3/6af7f7dda66c7c28e3364da96dd1ebd405d02592c0d7d85023
#   Building wheel for cudf-cu11 (pyproject.toml) ... done
#   Created wheel for cudf-cu11: filename=cudf_cu11-25.6.0-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl size=1595292 sha256=80f9c665b4aff8f1da54be6542f39f5059f271f726682af0a72694d08820952c
#   Stored in directory: /root/.cache/pip/wheels/c7/78/d0/b8306ab2237fa5544a9fa10c15d6914eb94663f04735e6b9a4
#   Building wheel for cuvs-cu11 (pyproject.toml) ... done
#   Created wheel for cuvs-cu11: filename=cuvs_cu11-25.6.1-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl size=832720 sha256=ee35bc091d0d40d269e98328710d01f74d4c0c034b4df4ad60120ec057541be3
#   Stored in directory: /root/.cache/pip/wheels/22/da/ff/6a5af729c96b029e134ac6244459ed12d27e2131eaa07a507d
#   Building wheel for dask-cudf-cu11 (pyproject.toml) ... done
#   Created wheel for dask-cudf-cu11: filename=dask_cudf_cu11-25.6.0-py3-none-any.whl size=50791 sha256=17c718ff89ea4b6ad4c6e43681cbc0a82d4bcffda0d68373b5371e3a2b4912c7
#   Stored in directory: /root/.cache/pip/wheels/48/fc/e8/f5350864d3ca6cba57bd1ec14f9532a43833824e3261eaafed
#   Building wheel for libcuml-cu11 (pyproject.toml) ... done
#   Created wheel for libcuml-cu11: filename=libcuml_cu11-25.6.0-py3-none-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl size=139884067 sha256=c724404be05ddef5529929775bfdc09e2dea4eb0ddc6f1c0aa89f9fff175717c
#   Stored in directory: /root/.cache/pip/wheels/4c/e4/db/f166cc28a47cf6faa8e4864900f108c4d084eefeb04796b3b2
#   Building wheel for pylibraft-cu11 (pyproject.toml) ... done
#   Created wheel for pylibraft-cu11: filename=pylibraft_cu11-25.6.0-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl size=855049 sha256=f98fa3055825f1f94d77af39a712c693ae6ed7e056d141997a10d39e22090f7e
#   Stored in directory: /root/.cache/pip/wheels/51/84/6d/ac7987d927d2d548510917a56ebd3802af0274caf7dd0da644
#   Building wheel for raft-dask-cu11 (pyproject.toml) ... done
#   Created wheel for raft-dask-cu11: filename=raft_dask_cu11-25.6.0-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl size=318535737 sha256=31b5bdb38e4121a3d593cdc72ac4803aed2daabdf112c7ee5259ac84aaa830db
#   Stored in directory: /root/.cache/pip/wheels/dd/fa/f7/80d51c01884e67f7c224706a7921d6a70c4fddcb05263a8a43
#   Building wheel for rmm-cu11 (pyproject.toml) ... done
#   Created wheel for rmm-cu11: filename=rmm_cu11-25.6.0-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl size=1109402 sha256=6640426f7fba4a3f6a7fe86e2653c7e78718f1087763b069484f1892fa937296
#   Stored in directory: /root/.cache/pip/wheels/9c/fd/1b/78e477f3601bd35ca5d2a31403654c203f60740442cce3eeaf
#   Building wheel for distributed-ucxx-cu11 (pyproject.toml) ... done
#   Created wheel for distributed-ucxx-cu11: filename=distributed_ucxx_cu11-0.44.0-py3-none-any.whl size=25702 sha256=5a550f6e7da53da0356bb5f917665591b4ff61d29200cc9e9c2717dd7307f55a
#   Stored in directory: /root/.cache/pip/wheels/ad/c1/f9/f829f83e4d945bfa061397d75847b4355693e4098e90504690
#   Building wheel for libcudf-cu11 (pyproject.toml) ... done
#   Created wheel for libcudf-cu11: filename=libcudf_cu11-25.6.0-py3-none-manylinux_2_28_x86_64.whl size=445866473 sha256=2fa1a18f112b870420417e48faea4a74877280ea053a1d414e2bbc8b532757ed
#   Stored in directory: /root/.cache/pip/wheels/71/65/ec/ca281230a07eb41cc28d051394d4e6c70e6d1bca56f17cedfc
#   Building wheel for libcuvs-cu11 (pyproject.toml) ... done
#   Created wheel for libcuvs-cu11: filename=libcuvs_cu11-25.6.1-py3-none-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl size=1039079924 sha256=3d0625fed2d4485d446a6000ed187bd8c84bc3eaf7f0a30869ae4431eb777d6f
#   Stored in directory: /root/.cache/pip/wheels/cb/28/77/2f59012a9489dc6d1de90883c03809503783c5791ee0bba8f3
#   Building wheel for libraft-cu11 (pyproject.toml) ... done
#   Created wheel for libraft-cu11: filename=libraft_cu11-25.6.0-py3-none-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl size=18865344 sha256=6565c612fed4fac91e8dd54400fe42368d21a8db867cc95cb35c00eb9f87a56e
#   Stored in directory: /root/.cache/pip/wheels/c0/45/2a/5edf43eb2b111419bf050029c729006ef5be06527b5c57b2d0
#   Building wheel for librmm-cu11 (pyproject.toml) ... done
#   Created wheel for librmm-cu11: filename=librmm_cu11-25.6.0-py3-none-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl size=3564591 sha256=495a50223258c5e41a45f5e046f05568099830d9c43b61b122329d4916cfed84
#   Stored in directory: /root/.cache/pip/wheels/fe/e3/e4/95384b96d18e0be643dd82fa693dff94aeba31377efdccd3fc
#   Building wheel for pylibcudf-cu11 (pyproject.toml) ... done
#   Created wheel for pylibcudf-cu11: filename=pylibcudf_cu11-25.6.0-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl size=27686315 sha256=fed3a483b87f53ee2c3dc6dd38af7a0079e4b8f2a997a83c8387448d4d84a3d9
#   Stored in directory: /root/.cache/pip/wheels/5e/67/23/fe585ae61843326ee04e857007a1a2ad5bcb2b4e540efca018
#   Building wheel for ucx-py-cu11 (pyproject.toml) ... done
#   Created wheel for ucx-py-cu11: filename=ucx_py_cu11-0.44.0-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl size=2237923 sha256=4a1f9b825f87db442e94d3734a51377519cd5526ef637727f294ad8a6f2545bb
#   Stored in directory: /root/.cache/pip/wheels/51/cf/3e/e655f5bc539ea987cb9c260457bf68832ce3b444a4e24bf388
#   Building wheel for libkvikio-cu11 (pyproject.toml) ... done
#   Created wheel for libkvikio-cu11: filename=libkvikio_cu11-25.6.0-py3-none-manylinux_2_28_x86_64.whl size=58621009 sha256=3e919db3f6cc4331e5003c085b3c773865dd19d685e49b6dd7e6a9abd32bdc8b
#   Stored in directory: /root/.cache/pip/wheels/55/ba/ce/2e9f259b03380fa7f6a44834f2e92dfd529f4cadc50432cc5d
#   Building wheel for ucxx-cu11 (pyproject.toml) ... done
#   Created wheel for ucxx-cu11: filename=ucxx_cu11-0.44.0-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl size=681883 sha256=e49509a64bc4e1646aa5b182c4043d80e846a6a9e7979ea44c81134d4bd1caae
#   Stored in directory: /root/.cache/pip/wheels/7c/9e/07/194173fd03d1922244c493b56c68c1c3c29c7c7595091cf955
#   Building wheel for libucxx-cu11 (pyproject.toml) ... done
#   Created wheel for libucxx-cu11: filename=libucxx_cu11-0.44.0-py3-none-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl size=507546 sha256=00836168b58720e66699f8c3b0de991a3eabe265e8185c5737e38f6a08e76afd
#   Stored in directory: /root/.cache/pip/wheels/19/20/7b/6856dc2db4e95f5d5f62aa61a42abdd2e189df66eb47a17a69
#   Building wheel for fvcore (setup.py) ... done
#   Created wheel for fvcore: filename=fvcore-0.1.5.post20221221-py3-none-any.whl size=61397 sha256=29615e6360e19fe8e86b8c6512eb906499cb8bbc00f14b420bbd75eac5ab5f2e
#   Stored in directory: /root/.cache/pip/wheels/ed/9f/a5/e4f5b27454ccd4596bd8b62432c7d6b1ca9fa22aef9d70a16a
#   Building wheel for iopath (setup.py) ... done
#   Created wheel for iopath: filename=iopath-0.1.10-py3-none-any.whl size=31527 sha256=d6e8d561b03a13850987598e95659596279f95665add9ff9708321f92ca7adec
#   Stored in directory: /root/.cache/pip/wheels/7c/96/04/4f5f31ff812f684f69f40cb1634357812220aac58d4698048c
# Successfully built dinov2 xformers cuml-cu11 cudf-cu11 cuvs-cu11 dask-cudf-cu11 libcuml-cu11 pylibraft-cu11 raft-dask-cu11 rmm-cu11 distributed-ucxx-cu11 libcudf-cu11 libcuvs-cu11 libraft-cu11 librmm-cu11 pylibcudf-cu11 ucx-py-cu11 libkvikio-cu11 ucxx-cu11 libucxx-cu11 fvcore iopath
# Failed to build mmcv-full
# ERROR: ERROR: Failed to build installable wheels for some pyproject.toml based projects (mmcv-full)

# %% [markdown]
# ## Utilities

# %%
import math
import itertools
from functools import partial

import torch
import torch.nn.functional as F
from mmseg.apis import init_segmentor, inference_segmentor

import dinov2.eval.segmentation.models


class CenterPadding(torch.nn.Module):
    def __init__(self, multiple):
        super().__init__()
        self.multiple = multiple

    def _get_pad(self, size):
        new_size = math.ceil(size / self.multiple) * self.multiple
        pad_size = new_size - size
        pad_size_left = pad_size // 2
        pad_size_right = pad_size - pad_size_left
        return pad_size_left, pad_size_right

    @torch.inference_mode()
    def forward(self, x):
        pads = list(itertools.chain.from_iterable(self._get_pad(m) for m in x.shape[:1:-1]))
        output = F.pad(x, pads)
        return output


def create_segmenter(cfg, backbone_model):
    model = init_segmentor(cfg)
    model.backbone.forward = partial(
        backbone_model.get_intermediate_layers,
        n=cfg.model.backbone.out_indices,
        reshape=True,
    )
    if hasattr(backbone_model, "patch_size"):
        model.backbone.register_forward_pre_hook(lambda _, x: CenterPadding(backbone_model.patch_size)(x[0]))
    model.init_weights()
    return model
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipython-input-176059793.py in <cell line: 0>()
#       5 import torch
#       6 import torch.nn.functional as F
# ----> 7 from mmseg.apis import init_segmentor, inference_segmentor
#       8
#       9 import dinov2.eval.segmentation.models
#
# ModuleNotFoundError: No module named 'mmseg'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %% [markdown]
# ## Load pretrained backbone

# %%
BACKBONE_SIZE = "small" # in ("small", "base", "large" or "giant")


backbone_archs = {
    "small": "vits14",
    "base": "vitb14",
    "large": "vitl14",
    "giant": "vitg14",
}
backbone_arch = backbone_archs[BACKBONE_SIZE]
backbone_name = f"dinov2_{backbone_arch}"

backbone_model = torch.hub.load(repo_or_dir="facebookresearch/dinov2", model=backbone_name)
backbone_model.eval()
backbone_model.cuda()

# %% [markdown]
# ## Load pretrained segmentation head

# %%
import urllib

import mmcv
from mmcv.runner import load_checkpoint


def load_config_from_url(url: str) -> str:
    with urllib.request.urlopen(url) as f:
        return f.read().decode()


HEAD_SCALE_COUNT = 3 # more scales: slower but better results, in (1,2,3,4,5)
HEAD_DATASET = "voc2012" # in ("ade20k", "voc2012")
HEAD_TYPE = "ms" # in ("ms, "linear")


DINOV2_BASE_URL = "https://dl.fbaipublicfiles.com/dinov2"
head_config_url = f"{DINOV2_BASE_URL}/{backbone_name}/{backbone_name}_{HEAD_DATASET}_{HEAD_TYPE}_config.py"
head_checkpoint_url = f"{DINOV2_BASE_URL}/{backbone_name}/{backbone_name}_{HEAD_DATASET}_{HEAD_TYPE}_head.pth"

cfg_str = load_config_from_url(head_config_url)
cfg = mmcv.Config.fromstring(cfg_str, file_format=".py")
if HEAD_TYPE == "ms":
    cfg.data.test.pipeline[1]["img_ratios"] = cfg.data.test.pipeline[1]["img_ratios"][:HEAD_SCALE_COUNT]
    print("scales:", cfg.data.test.pipeline[1]["img_ratios"])

model = create_segmenter(cfg, backbone_model=backbone_model)
load_checkpoint(model, head_checkpoint_url, map_location="cpu")
model.cuda()
model.eval()

print(cfg_str)

# %% [markdown]
# ## Load sample image

# %%
import urllib

from PIL import Image


def load_image_from_url(url: str) -> Image:
    with urllib.request.urlopen(url) as f:
        return Image.open(f).convert("RGB")


EXAMPLE_IMAGE_URL = "https://dl.fbaipublicfiles.com/dinov2/images/example.jpg"


image = load_image_from_url(EXAMPLE_IMAGE_URL)
display(image)

# %% [markdown]
# ## Semantic segmentation on sample image

# %%
import numpy as np

import dinov2.eval.segmentation.utils.colormaps as colormaps


DATASET_COLORMAPS = {
    "ade20k": colormaps.ADE20K_COLORMAP,
    "voc2012": colormaps.VOC2012_COLORMAP,
}


def render_segmentation(segmentation_logits, dataset):
    colormap = DATASET_COLORMAPS[dataset]
    colormap_array = np.array(colormap, dtype=np.uint8)
    segmentation_values = colormap_array[segmentation_logits + 1]
    return Image.fromarray(segmentation_values)


array = np.array(image)[:, :, ::-1] # BGR
segmentation_logits = inference_segmentor(model, array)[0]
segmented_image = render_segmentation(segmentation_logits, HEAD_DATASET)
display(segmented_image)

# %% [markdown]
# ## Load pretrained segmentation model (Mask2Former)

# %%
import dinov2.eval.segmentation_m2f.models.segmentors

CONFIG_URL = f"{DINOV2_BASE_URL}/dinov2_vitg14/dinov2_vitg14_ade20k_m2f_config.py"
CHECKPOINT_URL = f"{DINOV2_BASE_URL}/dinov2_vitg14/dinov2_vitg14_ade20k_m2f.pth"

cfg_str = load_config_from_url(CONFIG_URL)
cfg = mmcv.Config.fromstring(cfg_str, file_format=".py")

model = init_segmentor(cfg)
load_checkpoint(model, CHECKPOINT_URL, map_location="cpu")
model.cuda()
model.eval()

# %% [markdown]
# ## Semantic segmentation on sample image

# %%
array = np.array(image)[:, :, ::-1] # BGR
segmentation_logits = inference_segmentor(model, array)[0]
segmented_image = render_segmentation(segmentation_logits, "ade20k")
display(segmented_image)
